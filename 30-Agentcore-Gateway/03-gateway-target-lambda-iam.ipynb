# %% [markdown]
# # MCPify your AWS Lambda with Gateway IAM role Inbound
# ## Transform AWS Lambda functions into secure MCP tools with Bedrock AgentCore Gateway
#
# ## Overview
# Bedrock AgentCore Gateway provides customers a way to turn their existing AWS Lambda functions into fully-managed MCP servers without needing to manage infra or hosting. Gateway will provide a uniform Model Context Protocol (MCP) interface across all these tools. Gateway employs a dual authentication model to ensure secure access control for both incoming requests and outbound connections to target resources. The framework consists of two key components: Inbound Auth, which validates and authorizes users attempting to access gateway targets, and Outbound Auth, which enables the gateway to securely connect to backend resources on behalf of authenticated users. Gateways uses IAM role to authorize the calls to AWS Lambda functions for outbound authorization.
#
# In this example, we will demonstrate both inbound and outbound authorization using IAM roles.
#
# ![How does it work](images/lambda-gw-iam-inbound.png)
#
# ### Tutorial Details
#
#
# | Information          | Details                                                   |
# |:---------------------|:----------------------------------------------------------|
# | Tutorial type        | Interactive                                               |
# | AgentCore components | AgentCore Gateway                                         |
# | Agentic Framework    | Strands Agents                                            |
# | Gateway Target type  | AWS Lambda                                                |
# | Inbound Auth         | AAWS IAM                                                  |
# | Outbound Auth        | AWS IAM                                                   |
# | LLM model            | Anthropic Claude Sonnet 3.7, Amazon Nova Pro              |
# | Tutorial components  | Creating AgentCore Gateway and Invoking AgentCore Gateway |
# | Tutorial vertical    | Cross-vertical                                            |
# | Example complexity   | Easy                                                      |
# | SDK used             | boto3                                                     |
#
# In the first part of the tutorial we will create AmazonCore Gateway targets for Lambda
#
# ### Tutorial Architecture
# In this tutorial we will transform operations defined in AWS lambda function into MCP tools and host it in Bedrock AgentCore Gateway. We will demonstrate the ingress auth using AWS IAM credentials in AWS Sigv4 header.
# For demonstration purposes, we will use a Strands Agent using Amazon Bedrock models.
# In our example we will use a very simple agent with two tools: get_order and update_order.

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Jupyter notebook (Python kernel)
# * uv
# * AWS credentials
# * Access of Nova Pro via AWS console
# * Amazon Bedrock AgentCore SDK
# * Strand Agents

# %% [markdown]
# ## Configuring Authentication for Incoming AgentCore Gateway Requests
# AgentCore Gateway provides secure connections via inbound and outbound authentication. For the inbound authentication, the AgentCore Gateway now supports AWS IAM credentials/identities in addtion to OAuth to call the gateway. If a tool needs access to external resources, the AgentCore Gateway can use outbound authentication via API Key, IAM or OAuth Token to allow or deny the access to the external resource.
#
# During the inbound authorization flow, an agent or the MCP client uses AWS Signature V4 signed requests that will be used for authentication and authorize against IAM permissions to access the AgentCore Gateway. AgentCore Gateway then validates AWS IAM credentials/identities and performs inbound authorization.
#
# If the tool running in AgentCore Gateway needs to access external resources, IAM role will retrieve credentials of downstream resources for the Gateway target. AgentCore Gateway pass the authorization credentials to the caller to get access to the downstream API.

# %%
# !pip install -r requirements.txt

# %%
# Set AWS credentials if not using Amazon SageMaker notebook
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
#os.environ['AWS_ACCESS_KEY_ID']=''
#os.environ['AWS_SECRET_ACCESS_KEY']=''
os.environ['AWS_DEFAULT_REGION']='us-west-2' # set the AWS region

# %%
# Now you can import utils
import utils
#### Create a sample AWS Lambda function that you want to convert into MCP tools
lambda_resp = utils.create_gateway_lambda("lambda_function_code.zip")
if lambda_resp is not None:
    if lambda_resp['exit_code'] == 0:
        print("Lambda function created with ARN: ", lambda_resp['lambda_function_arn'])
    else:
        print("Lambda function creation failed with message: ", lambda_resp['lambda_function_arn'])
# Out:
# Reading code from zip file
# Creating IAM role for lambda function
# IAM role gateway_lambda_iamrole already exists. Using the same ARN arn:aws:iam::977099023120:role/gateway_lambda_iamrole
# Creating lambda function
# Lambda function created with ARN:  arn:aws:lambda:us-west-2:977099023120:function:gateway_lambda

# %%
#### Create an IAM role for the Gateway to assume
import utils
agentcore_gateway_iam_role = utils.create_agentcore_gateway_role("sample-lambdagateway")
print("Agentcore gateway role ARN: ", agentcore_gateway_iam_role['Role']['Arn'])
# Out:
# attaching role policy agentcore-sample-lambdagateway-role
# Agentcore gateway role ARN:  arn:aws:iam::977099023120:role/agentcore-sample-lambdagateway-role

# %% [markdown]
# # Create the Gateway with Amazon IAM Authorizer for inbound authorization

# %%
import time
import boto3
# CreateGateway with Amazon IAM. 
gateway_client = boto3.client('bedrock-agentcore-control', region_name = os.environ['AWS_DEFAULT_REGION'])

create_response = gateway_client.create_gateway(name='TestGWforLambdaIAM',
    roleArn = agentcore_gateway_iam_role['Role']['Arn'], # The IAM Role must have permissions to create/list/get/delete Gateway 
    protocolType='MCP',
    authorizerType='AWS_IAM',
    description='AgentCore Gateway with AWS Lambda target type using Amazon IAM for ingress auth'
)
print(create_response)
# Retrieve the GatewayID used for GatewayTarget creation
gatewayID = create_response["gatewayId"]
gatewayURL = create_response["gatewayUrl"]
print(gatewayID)
time.sleep(10)
# Out:
# {'ResponseMetadata': {'RequestId': 'eb118c0e-25c8-4f56-9d19-d4ff04ef0470', 'HTTPStatusCode': 202, 'HTTPHeaders': {'date': 'Fri, 31 Oct 2025 05:08:14 GMT', 'content-type': 'application/json', 'content-length': '644', 'connection': 'keep-alive', 'x-amzn-requestid': 'eb118c0e-25c8-4f56-9d19-d4ff04ef0470', 'x-amzn-remapped-x-amzn-requestid': '21aa8b38-f156-4c6f-a372-23ad1fc0221e', 'x-amzn-remapped-content-length': '644', 'x-amzn-remapped-connection': 'keep-alive', 'x-amz-apigw-id': 'TS-Z0H28PHcERDw=', 'x-amzn-trace-id': 'Root=1-6904443e-729568b7181bb8dc0db2fa6d', 'x-amzn-remapped-date': 'Fri, 31 Oct 2025 05:08:14 GMT'}, 'RetryAttempts': 0}, 'gatewayArn': 'arn:aws:bedrock-agentcore:us-west-2:977099023120:gateway/testgwforlambdaiam-haow78cofs', 'gatewayId': 'testgwforlambdaiam-haow78cofs', 'gatewayUrl': 'https://testgwforlambdaiam-haow78cofs.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp', 'createdAt': datetime.datetime(2025, 10, 31, 5, 8, 14, 523858, tzinfo=tzutc()), 'updatedAt': datetime.datetime(2025, 10, 31, 5, 8, 14, 523868, tzinfo=tzutc()), 'status': 'CREATING', 'name': 'TestGWforLambdaIAM', 'description': 'AgentCore Gateway with AWS Lambda target type using Amazon IAM for ingress auth', 'roleArn': 'arn:aws:iam::977099023120:role/agentcore-sample-lambdagateway-role', 'protocolType': 'MCP', 'authorizerType': 'AWS_IAM', 'workloadIdentityDetails': {}}
# testgwforlambdaiam-haow78cofs

# %% [markdown]
# # Create an AWS Lambda target and transform into MCP tools

# %%
# Replace the AWS Lambda function ARN below
lambda_target_config = {
    "mcp": {
        "lambda": {
            "lambdaArn": 'arn:aws:lambda:us-west-2:977099023120:function:gateway_lambda', # Replace this with your AWS Lambda function ARN
            "toolSchema": {
                "inlinePayload": [
                    {
                        "name": "get_order_tool",
                        "description": "tool to get the order",
                        "inputSchema": {
                            "type": "object",
                            "properties": {
                                "orderId": {
                                    "type": "string"
                                }
                            },
                            "required": ["orderId"]
                        }
                    },                    
                    {
                        "name": "update_order_tool",
                        "description": "tool to update the orderId",
                        "inputSchema": {
                            "type": "object",
                            "properties": {
                                "orderId": {
                                    "type": "string"
                                }
                            },
                            "required": ["orderId"]
                        }
                    }
                ]
            }
        }
    }
}

credential_config = [ 
    {
        "credentialProviderType" : "GATEWAY_IAM_ROLE"
    }
]
targetname='LambdaUsingSDK'
response = gateway_client.create_gateway_target(
    gatewayIdentifier=gatewayID,
    name=targetname,
    description='Lambda Target using SDK',
    targetConfiguration=lambda_target_config,
    credentialProviderConfigurations=credential_config)

# %% [markdown]
# # Create AWS IAM Role to Invoke Gateway

# %% [markdown]
# This below function creates or updates an IAM role that allows AWS Bedrock AgentCore to invoke a specified gateway. Builds and attaches an inline policy granting bedrock-agentcore:InvokeGateway permission for the given gateway ID.Also, configures a trust policy permitting both the Bedrock AgentCore service and the calling IAM entity (current_arn) to assume the role.

# %%
#### Create an IAM role to Invoke Gateway
current_role_arn = utils.get_current_role_arn()
print("Current role ARN: ", current_role_arn)

agentcore_gateway_iam_invoke_role = utils.create_gateway_invoke_tool_role("gateway-invoke-role",gatewayID , current_role_arn)
print("Role to invoke Agentcore gateway ARN: ", agentcore_gateway_iam_invoke_role['Role']['Arn'])
# Out:
# Current role ARN:  {'arn:aws:sts::977099023120:assumed-role/AWSReservedSSO_AdministratorAccess_8133186339cd89a9/chuongho@myhofamily.net'}
# Created new role: gateway-invoke-role
# Attempt 1/5: AccessDenied, retrying in 3s...
# Attempt 2/5: AccessDenied, retrying in 3s...
# Caller arn:aws:sts::977099023120:assumed-role/AWSReservedSSO_AdministratorAccess_8133186339cd89a9/chuongho@myhofamily.net can now assume role gateway-invoke-role
#  Role 'gateway-invoke-role' is ready and arn:aws:sts::977099023120:assumed-role/AWSReservedSSO_AdministratorAccess_8133186339cd89a9/chuongho@myhofamily.net can invoke the Bedrock Agent Gateway.
# Role to invoke Agentcore gateway ARN:  arn:aws:iam::977099023120:role/gateway-invoke-role

# %% [markdown]
# # Strands agent calling MCP tools of AWS Lambda using Bedrock AgentCore Gateway

# %% [markdown]
# #### Support for AWS IAM Authentication in MCP Client SDKs
#
# AWS IAM authentication is now supported for inbound requests to AgentCore Gateway, it's important to note that current open-source MCP Client SDKs have limited support for SigV4 authentication, particularly for streamable HTTP connections. However, AWS has provided a solution through the "Run Model Context Protocol (MCP) servers with AWS Lambda" project, which includes a crucial extension for SigV4 authentication with streaming HTTP connections.
#
# This implementation, available at the [AWS Labs GitHub repository](https://github.com/awslabs/run-model-context-protocol-servers-with-aws-lambda/tree/main), bridges the authentication gap for streaming connections and can be seamlessly integrated with popular agentic frameworks like Strands or LangChain. The StreamableHTTPTransportWithSigV4 class extends the standard MCP transport layer to handle AWS SigV4 signing while maintaining streaming capabilities, making it compatible with AgentCore Gateway's new IAM authentication feature.

# %%
# !pip3 install --upgrade strands-agents strands-agents-tools
from strands.models import BedrockModel

## The IAM credentials configured in ~/.aws/credentials should have access to Bedrock model
yourmodel = BedrockModel(
    model_id="us.amazon.nova-pro-v1:0",
    temperature=0.7,
)
# Out:
# Requirement already satisfied: strands-agents in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (1.13.0)
# Collecting strands-agents
#   Using cached strands_agents-1.14.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: strands-agents-tools in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (0.2.12)
# Collecting strands-agents-tools
#   Using cached strands_agents_tools-0.2.13-py3-none-any.whl.metadata (49 kB)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (1.40.61)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (1.40.61)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (0.17.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (4.25.1)
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (1.19.0)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (1.38.0)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (0.59b0)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (1.38.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (2.11.10)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents) (6.0.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (0.14.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.28.0)
# Requirement already satisfied: anyio>=4.5 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (4.11.0)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.4.3)
# Requirement already satisfied: httpx>=0.27.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (2.11.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (3.0.2)
# Requirement already satisfied: starlette>=0.27 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.49.1)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from mcp<2.0.0,>=1.11.0->strands-agents) (0.38.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.30.0->strands-agents) (3.23.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.59b0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.59b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (1.17.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.59b0)
# Requirement already satisfied: packaging>=18.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from opentelemetry-instrumentation==0.59b0->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.29.0->strands-agents) (1.17.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (3.13.2)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (0.4.0)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (1.2.0)
# Requirement already satisfied: pillow<12.0.0,>=11.2.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (11.3.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (2.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (14.2.0)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (1.26.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from strands-agents-tools) (9.1.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.22.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.14.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.8)
# Requirement already satisfied: wcwidth in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (2025.10.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.19.2)
# Requirement already satisfied: slack_sdk<4,>=3.37.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.37.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from anyio>=4.5->mcp<2.0.0,>=1.11.0->strands-agents) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx>=0.27.1->mcp<2.0.0,>=1.11.0->strands-agents) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.11.0->strands-agents) (1.2.1)
# Requirement already satisfied: click>=7.0 in /Users/chuongho/Library/CloudStorage/WorkDocsDrive-Documents/Workdocks - Working Files/Lunch and Learn/lunch_and_learn_demos/.venv/lib/python3.13/site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.11.0->strands-agents) (8.3.0)
# Using cached strands_agents-1.14.0-py3-none-any.whl (238 kB)
# Using cached strands_agents_tools-0.2.13-py3-none-any.whl (299 kB)
# Installing collected packages: strands-agents, strands-agents-tools
#   Attempting uninstall: strands-agents
#     Found existing installation: strands-agents 1.13.0
#     Uninstalling strands-agents-1.13.0:
#       Successfully uninstalled strands-agents-1.13.0
#   Attempting uninstall: strands-agents-tools━━━━ 0/2 [strands-agents]
#     Found existing installation: strands-agents-tools 0.2.12m [strands-agents]
#     Uninstalling strands-agents-tools-0.2.12: 0/2 [strands-agents]
#       Successfully uninstalled strands-agents-tools-0.2.12 [strands-agents]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [strands-agents-tools]ands-agents-tools]
# Successfully installed strands-agents-1.14.0 strands-agents-tools-0.2.13

# %%
from strands import Agent
import logging
from strands import Agent
import logging
from strands.tools.mcp.mcp_client import MCPClient
from mcp.client.streamable_http import streamablehttp_client 
from botocore.credentials import Credentials
from streamable_http_sigv4 import (
    streamablehttp_client_with_sigv4,
)

SERVICE="bedrock-agentcore"

# Configure the root strands logger. Change it to DEBUG if you are debugging the issue.
logging.getLogger("strands").setLevel(logging.INFO)

# Add a handler to see the logs
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s", 
    handlers=[logging.StreamHandler()]
)

def create_streamable_http_transport(mcp_url: str, access_token: str):
       return streamablehttp_client(mcp_url, headers={"Authorization": f"Bearer {access_token}"})

def create_streamable_http_transport_sigv4(mcp_url: str, key: str, secret: str, sessionToken: str, serviceName: str, awsRegion: str):
        iamcredentials = Credentials(
            access_key=key,
            secret_key=secret,
            token = sessionToken
        )
        return streamablehttp_client_with_sigv4(
            url=mcp_url,
            credentials=iamcredentials,
            service=serviceName,
            region=awsRegion,
        )

def get_full_tools_list(client):
    more_tools = True
    tools = []
    pagination_token = None
    while more_tools:
        tmp_tools = client.list_tools_sync(pagination_token=pagination_token)
        tools.extend(tmp_tools)
        if tmp_tools.pagination_token is None:
            more_tools = False
        else:
            more_tools = True 
            pagination_token = tmp_tools.pagination_token
    return tools

def call_tool_sync(client, tool_id,tool_name, parameters=None):
    # Call the tool (no pagination argument supported)
    response = client.call_tool_sync(
        tool_use_id=tool_id,
        name=tool_name,
        arguments=parameters
    )

    # Extract output content
    if hasattr(response, "results") and response.results:
        return response.results
    elif hasattr(response, "output") and response.output:
        return response.output
    elif hasattr(response, "content"):
        return response.content
    else:
        return response  # fallback
         
def run_agent(mcp_url: str,key: str, secret: str, sessionToken: str,serviceName: str, awsRegion: str):
    mcp_client = MCPClient(lambda: create_streamable_http_transport_sigv4(mcp_url,key,secret,sessionToken,serviceName, awsRegion))

    with mcp_client:
        tools = get_full_tools_list(mcp_client)
        print(f"Found the following tools: {[tool.tool_name for tool in tools]}")
        print(f"Tool name: {tools[0].tool_name}")
        
        
        agent = Agent(model=yourmodel,tools=tools) ## you can replace with any model you like
        print(f"Tools loaded in the agent are {agent.tool_names}")
        agent("Check the order status for order id 123 and show me the exact response from the tool")
        #call mcp with tool
        tool=tools[0].tool_name
        tool_id="get-order-id-123-call-1"
        result = call_tool_sync(
            mcp_client,
            tool_id,
            tool_name=tool,
            parameters={"orderId": "123"}
        )

        print(f"Tool Call result: {result['content'][0]['text']}")

# %% [markdown]
# Assume the IAM Gateway Invoke role and run the Agent

# %%
sts_client = boto3.client("sts")
response = sts_client.assume_role(
        RoleArn=agentcore_gateway_iam_invoke_role['Role']['Arn'],
        RoleSessionName="invoke_mcp_session",
        DurationSeconds=3600  # 1 hour, can be up to 12h for some roles
)

creds = response["Credentials"]

access=creds["AccessKeyId"]
secret=creds["SecretAccessKey"]
token=creds["SessionToken"]

# Run Agent with the credentials from this new gateway-invoke-role
time.sleep(10) 
run_agent(gatewayURL,access,secret,token, SERVICE, os.environ['AWS_DEFAULT_REGION'])
# Out:
# INFO | strands.telemetry.metrics | Creating Strands MetricsClient
# Found the following tools: ['LambdaUsingSDK___get_order_tool', 'LambdaUsingSDK___update_order_tool']
# Tool name: LambdaUsingSDK___get_order_tool
# Tools loaded in the agent are ['LambdaUsingSDK___get_order_tool', 'LambdaUsingSDK___update_order_tool']
# <thinking> To check the order status for order id 123, I need to use the `LambdaUsingSDK___get_order_tool` to retrieve the order details. </thinking>
#
# Tool #1: LambdaUsingSDK___get_order_tool
# The exact response from the tool is: "Order Id 123 is in shipped status".Tool Call result: {"statusCode":200,"body":"Order Id 123 is in shipped status"}

# %% [markdown]
# **Issue: if you get below error while executing below cell, it indicates incompatibily between pydantic and pydantic-core versions.**
#
# ```
# TypeError: model_schema() got an unexpected keyword argument 'generic_origin'
# ```
# **How to resolve?**
#
# You will need to make sure you have pydantic==2.7.2 and pydantic-core 2.27.2 that are both compatible. Restart the kernel once done.

# %% [markdown]
# # Clean up
#
# Additional resources are also created like IAM role, IAM Policies, Credentials provider and AWS Lambda functions that you might need to manually delete as part of the clean up. This depends on the example you run.

# %% [markdown]
# ## Delete the gateway (Optional)

# %%
import utils
utils.delete_gateway(gateway_client,gatewayID)
